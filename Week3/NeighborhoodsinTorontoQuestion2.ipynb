# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto Part 2

# %% [markdown]
# Obtaining the postal codes and transform into panda dataframe

# %%
# !pip3 install pandas lxml
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.1.4)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.6.2)
# Requirement already satisfied: numpy>=1.15.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (1.19.4)
# Requirement already satisfied: pytz>=2017.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

toronto_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

toronto_df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# The dataframe should consist of three columns: PostalCode, Borough, and Neighborhood.
# Therefore we'll rename "Postal Code" to "PostalCode" and "Neighbourhood" to "Neighborhood"

# %%
toronto_df.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)
toronto_df.rename(columns={'Neighbourhood': 'Neighborhood'}, inplace=True)

toronto_df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
list(toronto_df.columns.values)
# Out:
# ['PostalCode', 'Borough', 'Neighborhood']

# %% [markdown]
# Only process the cells that have an assigned borough

# %%
toronto_df.shape
# Out:
# (180, 3)

# %%
toronto_df_filtered = toronto_df[toronto_df['Borough'] != 'Not assigned']
toronto_df_filtered.reset_index(drop=True, inplace=True)
toronto_df_filtered.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
toronto_df_filtered.shape
# Out:
# (103, 3)

# %% [markdown]
# So, we have reduced our row size. Now, we are checking, if there are any  duplicated postal codes:

# %%
toronto_df_filtered['PostalCode'].value_counts()
# Out:
# M2M    1
# M5K    1
# M1L    1
# M5G    1
# M4X    1
# M2R    1
# M1X    1
# M6J    1
# M5M    1
# M2N    1
# M9A    1
# M8Z    1
# M5S    1
# M4J    1
# M9M    1
# M5R    1
# M6A    1
# M8Y    1
# M5B    1
# M5A    1
# M3A    1
# M4H    1
# M4M    1
# M9R    1
# M1R    1
# M5P    1
# M1W    1
# M3B    1
# M2H    1
# M9V    1
# M1G    1
# M5H    1
# M3N    1
# M4Y    1
# M4R    1
# M6B    1
# M5J    1
# M5W    1
# M3M    1
# M6E    1
# M4L    1
# M7A    1
# M3J    1
# M8W    1
# M6N    1
# M3H    1
# M4E    1
# M4G    1
# M3C    1
# M1H    1
# M4T    1
# M7Y    1
# M9B    1
# M4K    1
# M4B    1
# M9W    1
# M1E    1
# M4C    1
# M5C    1
# M5V    1
# M5T    1
# M4P    1
# M1T    1
# M7R    1
# M9C    1
# M4N    1
# M6P    1
# M1N    1
# M8V    1
# M1C    1
# M6G    1
# M1K    1
# M9P    1
# M1S    1
# M1V    1
# M6H    1
# M1P    1
# M1J    1
# M1B    1
# M6R    1
# M5L    1
# M9L    1
# M6S    1
# M3K    1
# M1M    1
# M2J    1
# M2L    1
# M4S    1
# M4A    1
# M2K    1
# M8X    1
# M6C    1
# M2P    1
# M4V    1
# M9N    1
# M4W    1
# M5E    1
# M5N    1
# M6M    1
# M6L    1
# M5X    1
# M3L    1
# M6K    1
# Name: PostalCode, dtype: int64

# %% [markdown]
# Since the row size is the same, all postal codes are unique.
#
# Assign all "Not assigned" neighborhood to the borough ones. Let's check these rows:

# %%
toronto_df_filtered[toronto_df_filtered['Neighborhood'] == 'Not assigned'].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Which means there is any not assigned Neighborhood value. Already, formated accordingly in the wiki page

# %%
row, col = toronto_df_filtered.shape

print('The row size is', row, 'and the column size is', col)
# Out:
# The row size is 103 and the column size is 3

# %% [markdown]
# Now, we need to get the latitude and the longitude coordinates of each neighborhood. First we'll try to read from geogratis.gc.ca's API service. If we get a failure, both lat and lon values will be obtained from the provided csv URL: http://cocl.us/Geospatial_data

# %%
geo_df = pd.read_csv('https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv')

print('shape', geo_df.shape)

geo_df.head()
# Out:
# shape (103, 3)
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
import requests

def getLatLang(post_code):
    lat = 0
    lon = 0
    try:
        geo_json = requests.get('http://geogratis.gc.ca/services/geolocation/en/locate?q=' + post_code).json()
        lat = geo_json[0]['geometry']['coordinates'][1]
        lon = geo_json[0]['geometry']['coordinates'][0]
    except:
        # Got an error. reading from csv.
        print('Error for', post_code, 'retrying with backup service')
        geo_df = pd.read_csv('https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv')
        lat = geo_df[geo_df['Postal Code']==post_code]['Latitude'].values[0]
        lon = geo_df[geo_df['Postal Code']==post_code]['Longitude'].values[0]
        
    return lat, lon

lat, lon = getLatLang('M1B')

print('M1B postal code geo','Latitude:',lat,'Longitude:',lon)
# Out:
# M1B postal code geo Latitude: 43.809444 Longitude: -79.193321

# %% [markdown]
# Now, we will append the latitute and longitude coordinates to the filterd dataframe.

# %%
lat_list =[]
lon_list = []

for pc in toronto_df_filtered['PostalCode']:
    lat,lon = getLatLang(pc)
    lat_list.append(lat)
    lon_list.append(lon)

toronto_df_filtered = toronto_df_filtered.assign(Latitude=pd.Series(lat_list))
toronto_df_filtered = toronto_df_filtered.assign(Longitude=pd.Series(lon_list))

toronto_df_filtered.head()
# Out:
# Error for M7R retrying with backup service
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.752804 -79.329590
# 1  43.723358 -79.312927
# 2  43.647398 -79.352920
# 3  43.724842 -79.451431
# 4  43.663681 -79.392097

# %%
toronto_df_filtered
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 32         M1J       Scarborough
# 33         M2J        North York
# 34         M3J        North York
# 35         M4J         East York
# 36         M5J  Downtown Toronto
# 37         M6J      West Toronto
# 38         M1K       Scarborough
# 39         M2K        North York
# 40         M3K        North York
# 41         M4K      East Toronto
# 42         M5K  Downtown Toronto
# 43         M6K      West Toronto
# 44         M1L       Scarborough
# 45         M2L        North York
# 46         M3L        North York
# 47         M4L      East Toronto
# 48         M5L  Downtown Toronto
# 49         M6L        North York
# 50         M9L        North York
# 51         M1M       Scarborough
# 52         M2M        North York
# 53         M3M        North York
# 54         M4M      East Toronto
# 55         M5M        North York
# 56         M6M              York
# 57         M9M        North York
# 58         M1N       Scarborough
# 59         M2N        North York
# 60         M3N        North York
# 61         M4N   Central Toronto
# 62         M5N   Central Toronto
# 63         M6N              York
# 64         M9N              York
# 65         M1P       Scarborough
# 66         M2P        North York
# 67         M4P   Central Toronto
# 68         M5P   Central Toronto
# 69         M6P      West Toronto
# 70         M9P         Etobicoke
# 71         M1R       Scarborough
# 72         M2R        North York
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.752804 -79.329590
# 1                                     Victoria Village  43.723358 -79.312927
# 2                            Regent Park, Harbourfront  43.647398 -79.352920
# 3                     Lawrence Manor, Lawrence Heights  43.724842 -79.451431
# 4          Queen's Park, Ontario Provincial Government  43.663681 -79.392097
# 5              Islington Avenue, Humber Valley Village  43.664909 -79.529373
# 6                                       Malvern, Rouge  43.809444 -79.193321
# 7                                            Don Mills  43.750324 -79.359451
# 8                      Parkview Hill, Woodbine Gardens  43.708580 -79.310875
# 9                             Garden District, Ryerson  43.658165 -79.378456
# 10                                           Glencairn  43.708305 -79.448235
# 11   West Deane Park, Princess Gardens, Martin Grov...  43.653290 -79.553780
# 12              Rouge Hill, Port Union, Highland Creek  43.787994 -79.158661
# 13                                           Don Mills  43.723652 -79.344154
# 14                                    Woodbine Heights  43.691784 -79.308029
# 15                                      St. James Town  43.651802 -79.375801
# 16                                  Humewood-Cedarvale  43.693565 -79.432060
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.642063 -79.575493
# 18                   Guildwood, Morningside, West Hill  43.769684 -79.173050
# 19                                         The Beaches  43.678986 -79.296967
# 20                                         Berczy Park  43.646156 -79.373474
# 21                                 Caledonia-Fairbanks  43.690041 -79.451767
# 22                                              Woburn  43.772373 -79.215134
# 23                                             Leaside  43.711300 -79.364098
# 24                                  Central Bay Street  43.656776 -79.385551
# 25                                            Christie  43.670315 -79.421577
# 26                                           Cedarbrae  43.771313 -79.240784
# 27                                   Hillcrest Village  43.803627 -79.356956
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.748138 -79.439285
# 29                                    Thorncliffe Park  43.704113 -79.346405
# 30                            Richmond, Adelaide, King  43.650085 -79.383011
# 31                        Dufferin, Dovercourt Village  43.666885 -79.438675
# 32                                 Scarborough Village  43.745644 -79.231232
# 33                        Fairview, Henry Farm, Oriole  43.782608 -79.351830
# 34                     Northwood Park, York University  43.768211 -79.489258
# 35       East Toronto, Broadview North (Old East York)  43.688450 -79.337379
# 36   Harbourfront East, Union Station, Toronto Islands  43.631242 -79.377812
